# %% [markdown]
# # 此文件是用来使用Colab工具提交代码到GitHub仓库的

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/explore")
# !ln -s /content/drive/MyDrive/.ssh /root/.ssh
# !cp -r /content/drive/MyDrive/.ssh /root/

# %%
commitMessage = input("commit message: ")

# !git add .
# !git config --global user.email "yxuiang.wang@gmail.com"
# !git config --global user.name "honghuhu"
# !git commit -m '$commitMessage'
# !git push
# Out:
# commit message: add cnn
# [ai 1eb4d62] add cnn
#  31 files changed, 171 insertions(+), 1 deletion(-)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/Tensorflow_03.ipynb (100%)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/datasets/test_signs.h5 (100%)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/datasets/train_signs.h5 (100%)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/images/hands.png (100%)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/images/thumbs_up.jpg (100%)
#  rename ai/{11_03_Tensorflow => 07_mini_batch/11_03_tensorflow}/tf_utils.py (100%)
#  rename ai/{09_Adam => 09_adam}/Adam.ipynb (100%)
#  rename ai/{09_Adam => 09_adam}/datasets/data.mat (100%)
#  rename ai/{09_Adam => 09_adam}/images/1Dgrad_kiank.png (100%)
#  rename ai/{09_Adam => 09_adam}/images/cost.jpg (100%)
#  rename ai/{09_Adam => 09_adam}/images/kiank_minibatch.png (100%)
#  rename ai/{09_Adam => 09_adam}/images/kiank_partition.png (100%)
#  rename ai/{09_Adam => 09_adam}/images/kiank_sgd.png (100%)
#  rename ai/{09_Adam => 09_adam}/images/kiank_shuffle.png (100%)
#  rename ai/{09_Adam => 09_adam}/images/opt_momentum.png (100%)
#  rename ai/{09_Adam => 09_adam}/opt_utils.py (100%)
#  rename ai/{09_Adam => 09_adam}/testCases.py (100%)
#  rename ai/{11_01_Tensorflow => 11_01_tensorflow}/Tensorflow_01.ipynb (100%)
#  rename ai/{11_01_Tensorflow => 11_01_tensorflow}/tf_utils.py (100%)
#  rename ai/{11_02_Tensorflow => 11_02_tensorflow}/Tensorflow_02.ipynb (100%)
#  rename ai/{11_02_Tensorflow => 11_02_tensorflow}/images/onehot.png (100%)
#  rename ai/{11_02_Tensorflow => 11_02_tensorflow}/tf_utils.py (100%)
#  create mode 100644 ai/14_16_cnn/14_01_CNN.ipynb
#  create mode 100644 ai/14_16_cnn/14_02_CNN.ipynb
#  create mode 100644 ai/14_16_cnn/16_UseTensorflowBuildCNN.ipynb
#  create mode 100644 ai/14_16_cnn/cnn_utils.py
#  create mode 100644 ai/14_16_cnn/datasets/test_signs.h5
#  create mode 100644 ai/14_16_cnn/datasets/train_signs.h5
#  create mode 100644 ai/14_16_cnn/images/thumbs_up.jpg
#  create mode 100644 ai/14_16_cnn/report.txt
#  rewrite explore/tools/colab-terminal.ipynb (95%)
# Counting objects: 14, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (14/14), 24.91 KiB | 1.66 MiB/s, done.
# Total 14 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 5 local objects.
# remote: This repository moved. Please use the new location:
# remote:   git@github.com:honghuhu/ai.git
# To github.com:honghuhu/explore.git
#    d2afdbf..1eb4d62  ai -> ai

# %% [markdown]
# ## git 其它命令

# %%
# !git branch --set-upstream-to=origin/ai ai
# !git pull
# Out:
# Branch 'ai' set up to track remote branch 'ai' from 'origin'.
# Warning: Permanently added the RSA host key for IP address '13.114.40.48' to the list of known hosts.
# Already up to date.

# %%
# !git remote -v
# Out:
# origin	git@github.com:honghuhu/explore.git (fetch)
# origin	git@github.com:honghuhu/explore.git (push)

# %%
# !git remote rm origin
# !git remote add origin git@github.com:honghuhu/explore.git

# %%
# !git reset --hard 8a92dd8bf0a9f5782e279a5528f33935f40c7dac && git push -f

# %%
# !git status && git diff

# %%
filePath = input("file path: ") ## 恢复当前文件
# !git checkout -- $filePath

# %%
### 克隆算法项目
import os
os.chdir("/content")
# !git clone git@github.com:honghuhu/explore.git
### 切换分支
# !cd explore && git checkout -b ai origin/ai
### 验证
# !cd /content/explore && git branch -a
# !rm -rf /content/explore

# %% [markdown]
# ## 以下命令是用来设置 github 通过 ssh 上传代码

# %%
# 生成 SSH 公钥
# !ssh-keygen -t rsa -C 'Grep'
# 拷贝 SSH 公钥到谷歌硬盘
# !cp -r /root/.ssh /content/drive/MyDrive/
# 软链接到当前用户
#!ln -s /content/drive/MyDrive/.ssh /root/.ssh
# 查看当前目录软链接
# !ls -al /root/.ssh
# 查看公钥
# !cat /root/.ssh/id_rsa.pub

# %%
# !rm ~/.ssh/known_hosts
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-91825f0b

# %%
# !cd ai/ && unzip *.zip
