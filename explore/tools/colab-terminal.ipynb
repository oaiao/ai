# %% [markdown]
# # 此文件是用来使用Colab工具提交代码到GitHub仓库的

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/explore")
# !ln -s /content/drive/MyDrive/.ssh /root/.ssh
# !cp -r /content/drive/MyDrive/.ssh /root/

# %%
commitMessage = input("commit message: ")

# !git add .
# !git config --global user.email "yxuiang.wang@gmail.com"
# !git config --global user.name "honghuhu"
# !git commit -m '$commitMessage'
# !git push

# %%
# !ls ai/18_residual_networks/
# !unzip ai/18_residual_networks/18\ 残差网络2x.zip

# %% [markdown]
# ## git 其它命令

# %%
# !git branch --set-upstream-to=origin/ai ai
# !git pull
# Out:
# Branch 'ai' set up to track remote branch 'ai' from 'origin'.
# Already up to date.

# %%
# !git remote -v
# Out:
# origin	git@github.com:honghuhu/explore.git (fetch)
# origin	git@github.com:honghuhu/explore.git (push)

# %%
# !git remote rm origin
# !git remote add origin git@github.com:honghuhu/explore.git

# %%
# !git reset --hard 8a92dd8bf0a9f5782e279a5528f33935f40c7dac && git push -f

# %%
# !git status && git diff

# %%
# !echo -e '\n' + input("file path: ") >> .gitignore ## 追加一行
# !cat .gitignore

# %%
filePath = input("file path: ") ## 恢复当前文件
# !git checkout -- $filePath
# Out:
# file path: .gitignore

# %%
### 克隆算法项目
import os
os.chdir("/content")
# !git clone git@github.com:honghuhu/explore.git
### 切换分支
# !cd explore && git checkout -b ai origin/ai
### 验证
# !cd /content/explore && git branch -a
# !rm -rf /content/explore

# %% [markdown]
# ## 以下命令是用来设置 github 通过 ssh 上传代码

# %%
# 生成 SSH 公钥
# !ssh-keygen -t rsa -C 'Grep'
# 拷贝 SSH 公钥到谷歌硬盘
# !cp -r /root/.ssh /content/drive/MyDrive/
# 软链接到当前用户
#!ln -s /content/drive/MyDrive/.ssh /root/.ssh
# 查看当前目录软链接
# !ls -al /root/.ssh
# 查看公钥
# !cat /root/.ssh/id_rsa.pub
# 新增到github配置中

# %%
# !rm ~/.ssh/known_hosts
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-91825f0b

# %%
# !cd ai/ && unzip *.zip
